# %% [markdown]
# ##Installing the dependencies

# %%
# !pip install -qU langchain-huggingface langchain-community langchain-groq langgraph faiss-cpu pypdf

# %% [markdown]
# ##Importing the required Libraries
# Loads system utilities, Colab user data access, and all LangChain, embedding, vector store, LLM, agent, tool, and memory components needed for the RAG pipeline.

# %%
import os
from google.colab import userdata
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain.tools import tool
from langgraph.checkpoint.memory import InMemorySaver

# %% [markdown]
# ## Loading the Groq API key
# Retrieves the Groq API key securely from Google Colab user secrets for authenticating the LLM.

# %%
from google.colab import userdata
from langchain_groq import ChatGroq

groq_api_key = userdata.get('GROQ_API_KEY')

# %% [markdown]
# ## Initializing the Groq language model
# Creates an LLM instance using Groq with the specified model for generating responses in the RAG pipeline.

# %%
llm = ChatGroq(
    api_key=groq_api_key,
    model='openai/gpt-oss-120b'  # or another available Groq model
)

# %% [markdown]
# ## Loading, chunking, and embedding the document
# Downloads the Transformer paper PDF, splits it into overlapping text chunks, generates local embeddings, and stores them in a FAISS vector index for retrieval.

# %%
# Load and process the Transformer Paper
loader = PyPDFLoader("https://arxiv.org/pdf/1706.03762.pdf")
docs = loader.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.split_documents(docs)

# Local Embeddings (MiniLM-L6-v2)
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vector_store = FAISS.from_documents(chunks, embeddings)
retriever = vector_store.as_retriever()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ##Defining a document search tool
# Creates a custom tool that queries the vector store to retrieve relevant sections from the research paper for agent use.

# %%
@tool
def search_paper(query: str) -> str:
    """Search the 'Attention is All You Need' research paper for specific technical details."""
    docs = retriever.invoke(query)
    return "\n\n".join([d.page_content for d in docs])

tools = [search_paper]

# %% [markdown]
# ## Initializing memory and creating the agent
# Sets up in-memory checkpointing, defines a research-focused agent with tool access, and configures a conversation thread for running the RAG demo.

# %%
# 1. Initialize Memory
memory = InMemorySaver()

# 2. Create Agent
system_msg = "You are a professional research assistant. Use the search_paper tool to provide accurate answers."
agent = create_agent(llm, tools=tools, checkpointer=memory, system_prompt=system_msg)

# 3. Running the Demo Conversation
config = {"configurable": {"thread_id": "final_project_user"}}

# %% [markdown]
# ##Interactions with llm

# %% [markdown]
# **Interaction 1**

# %%
print("--- Start Conversation ---")
# Interaction 1
res1 = agent.invoke({"messages": [("user", "Hi, I'm a student researching Transformers.")]}, config)
print(f"Bot: {res1['messages'][-1].content}")
# Out:
# --- Start Conversation ---
# Bot: Hello! I’d be happy to help with your research on Transformers.
#
# To give you the most useful information, could you let me know which aspects you’re focusing on? For example:
#
# - The core architecture (self‑attention, multi‑head attention, positional encodings, etc.)
# - Training objectives and optimization tricks (e.g., label smoothing, learning‑rate schedules)
# - Variants and extensions (BERT, GPT, Vision Transformers, etc.)
# - Applications or performance benchmarks on specific tasks
# - Implementation details or code‑level considerations
#
# Feel free to be as specific as you like, and I can pull the relevant sections from the original *“Attention Is All You Need”* paper or other sources to support your work.

# %% [markdown]
# **Interaction 2**

# %%
# Interaction 2
res2 = agent.invoke({"messages": [("user", "What core concepts mentioned about attention in the paper?")]}, config)
print(f"\nBot: {res2['messages'][-1].content}")
# Out:
# Bot: Below is a concise “cheat‑sheet” of the **core attention concepts that the original *Attention Is All You Need* (Vaswani et al., 2017) paper introduces**.
# I have pulled the exact wording from the paper (see the excerpts returned by the search tool) and added brief explanations so you can see how each idea fits into the overall Transformer architecture.
#
# ---
#
# ## 1.  The General Attention Function
#
# > “An attention function can be described as mapping a **query** and a set of **key‑value pairs** to an output, where the query, keys, values, and output are all vectors. The output is computed as a weighted sum of the values.”  *(Section 3.2 – “Attention”)*
#
# **What it means**
# * The model decides *how much* each value (e.g., a word representation) should contribute to the result for a given query (e.g., the current word we are processing).
# * The weights are produced by a **compatibility function** that measures similarity between the query and each key.
#
# ---
#
# ## 2.  Scaled Dot‑Product Attention
#
# > “We call our particular attention **‘Scaled Dot‑Product Attention’** … The input consists of queries and keys of dimension *dₖ*, and values of dimension *dᵥ*. We compute the dot products of the query with all keys, **divide each by √dₖ**, and apply a softmax function to obtain the weights on the values.”
# > “Attention(Q, K, V) = softmax( Q Kᵀ / √dₖ ) V.” *(Section 3.2.1)*
#
# **Key points**
#
# | Element | Description |
# |---------|-------------|
# | **Dot‑product** | Measures raw similarity between query *q* and each key *k*. |
# | **Scaling ( / √dₖ )** | Prevents the dot‑product magnitudes from growing with the dimensionality *dₖ*; without it the soft‑max would be pushed into regions with tiny gradients. |
# | **Softmax** | Turns the scaled scores into a probability distribution (the attention weights). |
# | **Weighted sum** | The final output is the sum of the values *V* weighted by those probabilities. |
# | **Matrix implementation** | The operation can be performed for *all* queries at once using matrix multiplication (highly efficient on GPUs). |
#
# *Why it matters*: It is the **only** attention primitive used throughout the Transformer; the rest of the model (multi‑head, self‑attention, encoder‑decoder attention) is built on top of it.
#
# ---
#
# ## 3.  Multi‑Head Attention
#
# > “Instead of performing a single attention function with *d_model*-dimensional keys, values and queries, we found it beneficial to **linearly project** the queries, keys and values *h* times with different, learned linear projections to *dₖ*, *dₖ* and *dᵥ* dimensions, respectively. On each of these projected versions we then perform the attention function in parallel, yielding *dᵥ*-dimensional outputs which are concatenated and again linearly transformed.” *(Section 3.2.2 – “Multi‑Head Attention”)*
#
# **Why use several heads?**
#
# | Reason | Explanation |
# |--------|-------------|
# | **Model multiple representation sub‑spaces** | Each head learns to focus on different aspects of the input (e.g., syntax, long‑range dependencies, coreference). |
# | **Stabilize gradients** | Splitting the model’s capacity across heads reduces the dimensionality of each attention sub‑space, making the dot‑product values more stable. |
# | **Increase expressivity without extra cost** | The total computational budget stays the same (the paper keeps *h·dₖ = d_model*), but the model can capture richer patterns. |
#
# ---
#
# ## 4.  Self‑Attention (Encoder & Decoder)
#
# * **Encoder self‑attention** – Every position in the encoder can attend to *all* positions of the same input sequence (including itself). This lets the encoder build contextualized representations in a single pass, without recurrence.
# * **Decoder self‑attention** – Similar to the encoder, but **masked** so that a position can only attend to earlier positions (preventing “cheating” during generation).
#
# The paper shows (Figure 2) that a stack of such self‑attention layers, combined with feed‑forward sub‑layers, replaces the recurrent or convolutional blocks used in earlier sequence‑to‑sequence models.
#
# ---
#
# ## 5.  Encoder‑Decoder (Cross) Attention
#
# After the decoder’s masked self‑attention, a **second attention sub‑layer** attends over the *output of the encoder* (the “memory”). This is sometimes called **“source‑target attention”**. It lets the decoder pull in relevant information from the entire source sentence while generating each target token.
#
# ---
#
# ## 6.  Positional Encoding (Why attention needs it)
#
# Because attention has no notion of token order, the authors add **positional encodings** (sinusoidal functions of the token index) to the input embeddings:
#
# > “Since the model contains no recurrence and no convolution, we inject information about the relative or absolute position of the tokens in the sequence.” *(Section 3.5)*
#
# These encodings enable the model to reason about sequence order while still using purely attention‑based layers.
#
# ---
#
# ## 7.  Residual Connections & Layer Normalization
#
# Each sub‑layer (self‑attention, cross‑attention, feed‑forward) is wrapped with a **residual connection** followed by **layer normalization**:
#
# > “We employ a residual connection around each of the two sub‑layers, followed by layer normalization.” *(Section 3.3 – “Add & Norm”)*
#
# This stabilizes training of deep stacks of attention layers.
#
# ---
#
# ## 8.  Summary Diagram (from the paper)
#
# ```
# Input Embedding + Positional Encoding
#         │
#    ┌────▼─────┐
#    │ Encoder  │  (N identical layers)
#    └────▲─────┘
#         │
#    ┌────▼─────┐
#    │ Decoder  │  (N identical layers)
#    └────▲─────┘
#         │
#    Linear + Softmax → Output tokens
# ```
#
# *Each encoder/decoder layer contains:*
#
# 1. **Multi‑Head Self‑Attention** (masked in the decoder).
# 2. **(Decoder only) Multi‑Head Encoder‑Decoder Attention.**
# 3. **Position‑wise Feed‑Forward Network.**
# 4. **Residual + Layer‑Norm** after each of the above.
#
# ---
#
# ### TL;DR – Core Attention Concepts
#
# | Concept | Paper definition / key formula | Why it matters |
# |---------|--------------------------------|----------------|
# | **Attention function** | Maps *query* + *key‑value set* → weighted sum of values. | General framework for focusing on relevant parts of a sequence. |
# | **Scaled Dot‑Product** | `Attention(Q,K,V) = softmax(QKᵀ / √dₖ) V` | Stable, efficient, and the primitive used everywhere. |
# | **Multi‑Head** | Parallel attention heads with different linear projections; concatenate results. | Allows the model to capture diverse relations simultaneously. |
# | **Self‑Attention** | Queries, keys, values all come from the same sequence (encoder or decoder). | Replaces recurrence; gives each token a global view of the sequence. |
# | **Encoder‑Decoder (Cross) Attention** | Decoder queries attend to encoder keys/values. | Bridges source and target sequences during generation. |
# | **Positional Encoding** | Added to token embeddings; sinusoidal functions of position. | Supplies order information to a purely attention‑based architecture. |
# | **Residual + Layer‑Norm** | `LayerNorm(x + Sublayer(x))` | Enables deep stacking of attention layers without vanishing/exploding gradients. |
#
# These ideas together constitute the **“Attention‑is‑All‑You‑Need”** paradigm and form the foundation for virtually every modern Transformer model (BERT, GPT, Vision Transformers, etc.).

# %% [markdown]
# **Interaction 3**

# %%
#Interaction 3
res3 = agent.invoke({"messages": [("user", "What did i ask earlier?")]}, config)
print(f"\nBot: {res3['messages'][-1].content}")
# Out:
# Bot: You asked for **the core concepts about attention that are described in the original *“Attention Is All You Need”* paper**. In response I listed and explained the main attention‑related ideas introduced there (the general attention function, Scaled Dot‑Product Attention, Multi‑Head Attention, self‑attention, encoder‑decoder (cross) attention, positional encodings, and the residual‑plus‑layer‑norm wrapper).

# %% [markdown]
# **Output and Observations**
#
# The system successfully retrieves relevant sections from the “Attention Is All You Need” paper and generates grounded responses based on the retrieved content. Technical questions related to attention mechanisms are answered using document-backed retrieval rather than free-form generation. The agent also maintains conversational context across multiple interactions, correctly recalling earlier user inputs. This confirms the correct integration of document loading, chunking, vector storage, retrieval, tool usage, and memory within the RAG pipeline.
